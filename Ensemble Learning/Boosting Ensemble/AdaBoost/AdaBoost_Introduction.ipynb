# %% [markdown]
# 1. Weak Learners ( In AdaBoost we use Weak Learners whose accuracy is near to 50%. Not too Much high)
# 2. Decision Stumps (Algorithm in which we make only one split)
# 3. +1 and -1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is UpSampling:-** The increase in importance the weights of Mis Classified Samples is called UpSampling.

# %% [markdown]
# **Formula for MisClassified and Correct Classified Points:-**
#
# **MisCLassified Weights:-**
#
# new_weight = current_weight * e^alpha
#
# **Correct Classified Weights:-**
#
# new_weight = current_weight * e^-alpha
