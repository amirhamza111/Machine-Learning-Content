# %% [markdown]
# ![Screenshot from 2025-07-01 16-08-26.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2025-07-01 16-13-26.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2025-07-01 16-16-10.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2025-07-01 16-19-54.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2025-07-01 16-29-52.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2025-07-03 18-51-20.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2025-07-03 19-10-17.png](data:image/png;base64,...)

# %% [markdown]
# In order to trian Decision Tree , we first find Entropy , Gini Impurity and Information Gain(IG).
#
# **Note:-**
# 1. Entropy and Impurity Should be Minimize
# 2. Information Gain should be Maximize.
